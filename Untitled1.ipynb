# %% [markdown]
# <a href="https://colab.research.google.com/github/seungminyum/python_CLIboard/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("== CLI 게시판 실행 ==")
i = 1
while True:
    cmd = input("명령어 ) ")

    if cmd == "exit":
      break

    elif cmd == "article write":
      input("제목 : ")
      input("내용 : ")
      print("{}번 글이 생성되었습니다".format(i))
      i += 1
    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : 안녕
# 내용 : 히히
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : 반가워
# 내용 : 하하
# 2번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : 그래
# 내용 : 이만
# 3번 글이 생성되었습니다
# 명령어 ) exit
# == CLI 게시판 종료 ==

# %%
print("== CLI 게시판 실행 ==")
i = 1
articles =[] #게시글 저장소

while True:
    cmd = input("명령어 ) ").strip() #공백을 지워주는 요소


    if cmd == "exit":
      break

    elif cmd == "article write":
      id = i
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body} #조립 != 저장
      #print(article)
      articles.append(article) #저장
      print("{}번 글이 생성되었습니다".format(i))
      i += 1

    elif cmd == "article list": #딕셔너리나 리스트로 저장, 저장한 다음에 꺼내써야함
      if not articles:
        print("게시글이 없습니다")
      else:
        print("===========================")
        print("   번호   /   제목   /   내용")
        for a in reversed(articles):
          print("  {}   /    {}    /   {}".format(a["id"], a["title"], a["body"]))
      print("===========================")

    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : hello
# 내용 : my name is
# 1번 글이 생성되었습니다
# 명령어 ) bye
# 지원하지 않는 기능입니다
# 명령어 ) article write
# 제목 : bye
# 내용 : see you soon
# 2번 글이 생성되었습니다
# 명령어 ) article list
# ...
#    번호   /   제목   /   내용
#   2   /    bye    /   see you soon
#   1   /    hello    /   my name is
# ...
# 명령어 ) exit
# == CLI 게시판 종료 ==

# %%
print("== CLI 게시판 실행 ==")
i = 1
articles =[] #게시글 저장소
ids = []
num =[]

while True:
    cmd = input("명령어 ) ").strip() #공백을 지워주는 요소


    if cmd == "exit":
      break

    elif cmd == "article write":
      id = i
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body} #조립 != 저장
      #print(article)
      articles.append(article) #저장
      print("{}번 글이 생성되었습니다".format(i))
      i += 1

    elif cmd == "article list": #딕셔너리나 리스트로 저장, 저장한 다음에 꺼내써야함
      if not articles:
        print("게시글이 없습니다")
      else:
        print("===========================")
        print("   번호   /   제목   /   내용")
        for a in reversed(articles):
          print("  {}   /    {}    /   {}".format(a["id"], a["title"], a["body"]))
      print("===========================")

    elif cmd.startswith("article delete"):
      cmdBits = cmd.split(" ")
      print(cmd.split[2])
     if not ids:
        print("{}번 글은 존재하지 않습니다".format(num))
     else:
      for a in
      print("{}번 글이 삭제되었습니다".format(a["id"]))

    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : asd
# 내용 : sdg
# 1번 글이 생성되었습니다
# 명령어 ) lkj
# 지원하지 않는 기능입니다
# 명령어 ) article write
# 제목 : as
# 내용 : gds
# 2번 글이 생성되었습니다
# 명령어 ) article delete 3
# 지원하지 않는 기능입니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1158/1178396664.py in <cell line: 0>()
#       6
#       7 while True:
# ----> 8     cmd = input("명령어 ) ").strip() #공백을 지워주는 요소
#       9
#      10
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
